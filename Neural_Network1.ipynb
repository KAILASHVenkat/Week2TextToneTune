# %% [markdown]
# <a href="https://colab.research.google.com/github/KAILASHVenkat/Week2TextToneTune/blob/main/Neural_Network1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import seaborn as sn
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('https://raw.githubusercontent.com/KAILASHVenkat/Week1TextToneTune/main/drug200.csv')

# %%
Sex_Mapping={"M":0,"F":1}
df["Sex"]=df["Sex"].map(Sex_Mapping)
bp_map={"HIGH":2,"NORMAL":1,"LOW":0}
df["BP"]=df["BP"].map(bp_map)
c_map={"HIGH":1,"NORMAL":0}
df["Cholesterol"]=df["Cholesterol"].map(c_map)
d_map={"DrugY":0,"drugA":1,"drugB":2,"drugC":3,"drugX":4}
df["Drug"]=df["Drug"].map(d_map)
df
# Out:
#      Age  Sex  BP  Cholesterol  Na_to_K  Drug
# 0     23    1   2            1   25.355     0
# 1     47    0   0            1   13.093     3
# 2     47    0   0            1   10.114     3
# 3     28    1   1            1    7.798     4
# 4     61    1   0            1   18.043     0
# ..   ...  ...  ..          ...      ...   ...
# 195   56    1   0            1   11.567     3
# 196   16    0   0            1   12.006     3
# 197   52    0   1            1    9.894     4
# 198   23    0   1            0   14.020     4
# 199   40    1   0            0   11.349     4
#
# [200 rows x 6 columns]

# %%
x=df[['Age','Sex','BP','Cholesterol','Na_to_K']]
y=df['Drug']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# %%
model1 = keras.Sequential([
    keras.layers.Dense(64, input_shape=(5,), activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(32, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(5, activation='softmax')
])

optimizer = keras.optimizers.Adam(learning_rate=0.01)  # Adjust the learning rate as needed
model1.compile(
    optimizer=optimizer,
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

model1.fit(x_train_scaled, y_train, epochs=20, validation_data=(x_test_scaled, y_test))
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 73ms/step - loss: 1.5014 - accuracy: 0.3812 - val_loss: 1.2498 - val_accuracy: 0.6500
# Epoch 2/20
# 5/5 [==============================] - 0s 19ms/step - loss: 1.2387 - accuracy: 0.5375 - val_loss: 0.9140 - val_accuracy: 0.7250
# Epoch 3/20
# 5/5 [==============================] - 0s 18ms/step - loss: 1.0922 - accuracy: 0.5750 - val_loss: 0.7501 - val_accuracy: 0.7500
# Epoch 4/20
# 5/5 [==============================] - 0s 19ms/step - loss: 0.9955 - accuracy: 0.6187 - val_loss: 0.6839 - val_accuracy: 0.7750
# Epoch 5/20
# 5/5 [==============================] - 0s 21ms/step - loss: 0.8094 - accuracy: 0.6812 - val_loss: 0.5970 - val_accuracy: 0.8000
# Epoch 6/20
# 5/5 [==============================] - 0s 18ms/step - loss: 0.7400 - accuracy: 0.6938 - val_loss: 0.5224 - val_accuracy: 0.8500
# Epoch 7/20
# ...
